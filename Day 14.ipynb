# %% [markdown]
# Visualization with Seaborn -> python to visualization the data (pandas , numpy)
#     Seaborn Versus Matplotlib
# 	Exploring Seaborn Plots
# 	Exploring Marathon Finishing Times
# Machine Learning
#     What Is Machine Learning?
# 	Qualitative Examples of Machine Learning Applications
# Introducing Scikit-Learn
#     Data Representation in Scikit-Learn
# 	Scikit-Learn’s Estimator API
# 	Application: Exploring Handwritten Digits

# %%
#matplotlib
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
rng = np.random.RandomState(0)
x = np.linspace(0, 10, 500)
y= np.sin(x)
plt.plot(x,y)

# %%
#seaborn 
sb.set()
plt.plot(x,y)

# %% [markdown]
# Multivariate Normal Explanation:
#
# normal dist -> univariate -> 1 dim
# Multivariate -->normal dist --> higher dim
# syntax-> multivariate_normal(mean, cov, size)
# covariance -> measurment b/w two random variables
#
# X, Y -> 2 random var
# E- Expected value
# cov(X,Y)=E[(X-E[X])(Y-E[Y])]
#
# FINDING THe cov using np -> np.cov(x)

# %%
#Exploring Seaborn Plots -> hist , kde, density


data = np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)
d=pd.DataFrame(data, columns=['x', 'y'])
for col in 'xy':
    plt.hist(d[col], alpha=0.5)

# %%
#KDE -> sb.kdeplot

import seaborn as sb
for col in 'xy':
    sb.kdeplot(d[col], shade=True)
# Out:
# C:\Users\bjawa\AppData\Local\Temp\ipykernel_60024\826755431.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sb.kdeplot(d[col], shade=True)
# C:\Users\bjawa\AppData\Local\Temp\ipykernel_60024\826755431.py:5: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sb.kdeplot(d[col], shade=True)

# %%
#adding two plots -> hist+kde

sb.distplot(d['x'])
sb.distplot(d['y'])
# Out:
# C:\Users\bjawa\AppData\Local\Temp\ipykernel_60024\98362615.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(d['x'])
# C:\Users\bjawa\AppData\Local\Temp\ipykernel_60024\98362615.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(d['y'])
# ...

# %%
#joinplot -> sb.joinplot

#--> kind --> kde, scatter , hex
with sb.axes_style('white'):
    sb.jointplot( d, kind='kde'); 

with sb.axes_style('white'):
    sb.jointplot( d, kind='scatter'); 

with sb.axes_style('white'):
    sb.jointplot( d,x='x', y='y', kind='hex');

# %%
#pair plots

i =sb.load_dataset('iris')
print(i)

sb.pairplot(i, hue='species')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#facegrid

tips=sb.load_dataset('tips')
print(tips)
tips["tip_pct"]=100 * tips['tip'] / tips['total_bill']
print(tips)
grid = sb.FacetGrid(tips, row="sex", col="time", margin_titles=True)
grid.map(plt.hist, "tip_pct", bins=np.linspace(0, 40, 15));
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
#      total_bill   tip     sex smoker   day    time  size    tip_pct
# 0         16.99  1.01  Female     No   Sun  Dinner     2   5.944673
# 1         10.34  1.66    Male     No   Sun  Dinner     3  16.054159
# ...

# %%
#factor plot / catplot

with sb.axes_style(style='ticks'):
    g = sb.catplot( data=tips, kind="box")
    g.set_axis_labels("Day", "Total Bill");

# %%
#https://raw.githubusercontent.com/jakevdp/marathon-data/master/marathon-data.csv
#Exploring Marathon Finishing Times

# %% [markdown]
# Machine Learning
#     What Is Machine Learning?
#     -> ML --> Prblm statement --> Sln --> Test & Validate
#
#     Eg: Gender classification  -> 2 (Male , Female)
#
#     1.I/p --> 4L Images(1.jpg, 2.jpg) (Diff races)
#     2.Identify the person in image is male / female (model)-> male , female
#     ---> How u teach/ Train the model => Algo , Deep Learning Techniques
#     ---> How u will test the model => validation , testing
#     3.O/P ---> 4 L images --> excel (Image name , gender , prediction rate )
#
# 	Qualitative Examples of Machine Learning Applications

# %% [markdown]
# ML Learning types:
#
#     1.Supervised Learning
#
#    Eg: Student --> Syllabus/ course content --> Write the exam (question are from the syllabus) ---> Answer
#
#     Model --> Traing data ---> Testing model (Trained data)  --> o/p --> 90%
#
#     2.Unsupervised Learning
#
#     Eg: Student --> Syllabus/ course content --> Write the exam (question are out of syllabus) ---> Answer
#
#      Model --> Traing data ---> Testing model (other data)  --> o/p --> 70%
#
#     3.Reinforcement Learning (If it doing a mistake --> it will rectify and then correct it)
#
#      Eg: Student --> Syllabus/ course content --> Write the exam (question are out of syllabus, syllabus ) ---> Answer
#      1.it is out of syllabus
#      2.I am learning that it is out of syllabus and i can assure it as 90%
#      3.I am learning the input as out of syllabus
#
#      Soln -> Correct --> reward
#      Soln --> incorrect --> it will punish itself -> correct it next time

# %% [markdown]
# Supervised Learning:
#     1.Classification
#         Image classification
#         Fraud Detection (usual / unusual )
#
#     2.Regression
#         Market forecasting
#         Weather forcating
#         Cricket win win forecasting
#
#
# Unsupervised Learning:
#     1.Clustering (mobile- charger , case , battery , head , earphone )
#         Recommendation model
#
#     2.Dimensionality Reduction (8l columns * 1m rows)
#         Data DR
#         Image 2MB --> 1B
#
# Reinforcement Learning:
#     1.Real time decisions
#         Chat GPT
#     2.Robot Naviagtion prgramming
#     3.AI Games

# %% [markdown]
# Classification :
#
#     Sln:
#     1.Algorithm
#     2.DL Technique
#
# Algorithms:
# 1.Naive Bayes Algorithm
# 2.Support Vector Machines (SVM)
# 3.Decision Tree
# 4.Random Forest
#
# DL : Neural Network
# 1.RNN, DNN, CNN , ANN , Transfer learning

# %% [markdown]
# 1.Classification
# 2.Regression
# 3.Clustering
# 4.Dimensionality reduction

# %%
#Classification
#Scikit-Learn , pandas ,numpy , matplotlib , seaborn 
from sklearn.datasets import make_blobs #--> To create a data set
from sklearn.svm import SVC #Support vector classifier
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

#Step 1 -> Creating a blob for classifier prblm for training data
X, y = make_blobs(n_samples=50, centers=2,
                  random_state=0, cluster_std=0.60) 
#Step 2 -> Applying Algo
clf = SVC(kernel='linear')
#Step 3 -> Fitting
clf.fit(X,y)


#Step 4 -> create a testing data

X2,_ = make_blobs(n_samples=80, centers=2,
                  random_state=0, cluster_std=0.80) 

X2=X2[50:]

#Step 5 ---> Predicting

y2=clf.predict(X2)


#Step 6 --> Visualization

#for Training Data 

#fig, ax = plt.subplots(figsize=(8, 6))
#point_style = dict(cmap='Paired', s=50)
#ax.scatter(X[:, 0], X[:, 1], c=y, **point_style)


fig, ax = plt.subplots(1, 2, figsize=(16, 6))
fig.subplots_adjust(left=0.0625, right=0.95, wspace=0.1)

#Visualization of lines in X2 data 
xx = np.linspace(-1, 4, 10)
yy = np.linspace(-2, 7, 10)
xy1, xy2 = np.meshgrid(xx, yy)
Z = np.array([clf.decision_function([t])
              for t in zip(xy1.flat, xy2.flat)]).reshape(xy1.shape)
line_style = dict(levels = [-1.0, 0.0, 1.0],
                  linestyles = ['dashed', 'solid', 'dashed'],
                  colors = 'gray', linewidths=1)



point_style = dict(cmap='Paired', s=50)

#For Test data X2
ax[0].scatter(X2[:, 0], X2[:, 1], c='gray', **point_style)
ax[0].axis([-1, 4, -2, 7])

#For Test data X2 with Line
ax[1].scatter(X2[:, 0], X2[:, 1], c=y2, **point_style)
ax[1].contour(xy1, xy2, Z, **line_style)
ax[1].axis([-1, 4, -2, 7])
# Out:
# C:\Users\bjawa\AppData\Local\Temp\ipykernel_145856\1202081344.py:50: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax[0].scatter(X2[:, 0], X2[:, 1], c='gray', **point_style)
# (-1.0, 4.0, -2.0, 7.0)
